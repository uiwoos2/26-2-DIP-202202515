# %% [markdown]
# <a href="https://colab.research.google.com/github/uiwoos2/26-2-DIP-202202515/blob/main/HW/HW00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# HW00.ipynb

# %%
I = plt.imread('IMG_001.jpg')
print(I.dtype, I.shape)
plt.imshow(I)
plt.title('Marina Bay Sands')
plt.show()
# Out:
# uint8 (5184, 3456, 3)

# %% [markdown]
# - Image file의 metadata를 확인하기

# %%
from PIL import Image
from PIL.ExifTags import TAGS

# %%
I = Image.open('IMG_001.jpg')
exifdata = I.getexif()
for tag_id in exifdata:
    tag = TAGS.get(tag_id, tag_id)
    data = exifdata.get(tag_id)
    print(f"{tag:25}: {data}")
# Out:
# ImageWidth               : 5184
# JpegIFOffset             : 11188
# JpegIFByteCount          : 12680
# Compression              : 6
# ImageLength              : 3456
# GPSInfo                  : 817
# ResolutionUnit           : 2
# ExifOffset               : 275
# Make                     : Canon
# Model                    : Canon EOS 100D
# Artist                   :
# Orientation              : 1
# YCbCrPositioning         : 2
# DateTime                 : 2023:02:21 20:26:02
# Copyright                :
# XResolution              : 72.0
# YResolution              : 72.0
